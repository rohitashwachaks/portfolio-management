# %%
import pandas as pd
import requests

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_weekly_adjusted&symbol=BSE:TATAMOTORS&interval=5min&apikey=F6S054OFH755WYAJ'
r = requests.get(url)
data = r.json()
data.keys()
# Out:
# dict_keys(['Meta Data', 'Weekly Adjusted Time Series'])

# %%
data['Meta Data']
# Out:
# {'1. Information': 'Weekly Adjusted Prices and Volumes',
#  '2. Symbol': 'BSE:TATAMOTORS',
#  '3. Last Refreshed': '2021-12-13',
#  '4. Time Zone': 'US/Eastern'}

# %%
pd.DataFrame(data['Weekly Adjusted Time Series']).T['5. adjusted close'].sort_index().astype('float').plot(figsize = (20,15))
# Out:
# <AxesSubplot:>
